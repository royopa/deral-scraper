# %%
import pandas as pd
import os

def get_pandas_dataframe_base(path_file_base):
    df = pd.read_csv(path_file_base, sep=';', encoding='utf8')
    return df

# %%
base_file_name = 'precos_deral_base.csv'
path_file_base = os.path.join('bases', base_file_name)
df = get_pandas_dataframe_base(path_file_base)
df.tail(5)
# Out:
#       dt_referencia        no_produto  \
# 34667    2018-04-24         erva-mate
# 34668    2018-04-24             suíno
# 34669    2018-04-24              vaca
# 34670    2018-04-24  café beneficiado
# 34671    2018-04-24          mandioca
#
#                                          no_indicador  vr_real
# 34667              Erva-mate folha em barranco arroba    15.80
# 34668         Suíno em pé tipo carne não integrado kg     2.81
# 34669                Vaca em pé (padrão corte) arroba   128.56
# 34670  Café beneficiado bebida dura - tipo 6 sc 60 Kg   398.02
# 34671         Mandioca padrão de amido 580 g tonelada   525.86

# %%
df = df.pivot(index='dt_referencia', columns='no_indicador', values='vr_real')
df.tail()
# Out:
# no_indicador   Arroz Agulhinha em casca tipo 1 sc 60 Kg  Boi em pé arroba  \
# dt_referencia
# 2018-04-18                                        46.22            141.17
# 2018-04-19                                        46.22            141.07
# 2018-04-20                                        46.22            141.06
# 2018-04-23                                        46.22            141.03
# 2018-04-24                                        46.22            140.83
#
# no_indicador   Café beneficiado bebida dura - tipo 6 sc 60 Kg  \
# dt_referencia
# 2018-04-18                                             397.98
# 2018-04-19                                             397.81
# 2018-04-20                                             398.17
# 2018-04-23                                             397.36
# 2018-04-24                                             398.02
#
# no_indicador   Café em coco kg renda  Erva-mate folha em barranco arroba  \
# dt_referencia
# 2018-04-18                      6.39                                15.8
# 2018-04-19                      6.39                                15.8
# 2018-04-20                      6.39                                15.8
# 2018-04-23                      6.39                                15.8
# 2018-04-24                      6.38                                15.8
#
# no_indicador   Feijão Carioca tipo 1 sc 60 Kg  Feijão preto tipo 1 sc 60 Kg  \
# dt_referencia
# 2018-04-18                              92.04                        103.60
# 2018-04-19                              96.97                        103.80
# 2018-04-20                              97.75                        104.98
# 2018-04-23                             101.70                        105.43
# 2018-04-24                             102.99                        106.94
#
# no_indicador   Mandioca padrão de amido 580 g tonelada  \
# dt_referencia
# 2018-04-18                                      534.59
# 2018-04-19                                      526.31
# 2018-04-20                                      526.31
# 2018-04-23                                      525.86
# 2018-04-24                                      525.86
#
# no_indicador   Milho amarelo tipo 1 sc 60 Kg  \
# dt_referencia
# 2018-04-18                             30.55
# 2018-04-19                             30.60
# 2018-04-20                             30.66
# 2018-04-23                             30.66
# 2018-04-24                             30.70
#
# no_indicador   Pesquisa descontinuada (Algodão)  \
# dt_referencia
# 2018-04-18                                  0.0
# 2018-04-19                                  0.0
# 2018-04-20                                  0.0
# 2018-04-23                                  0.0
# 2018-04-24                                  0.0
#
# no_indicador   Pesquisa descontinuada (Arroz em casca sequeiro)  \
# dt_referencia
# 2018-04-18                                                  0.0
# 2018-04-19                                                  0.0
# 2018-04-20                                                  0.0
# 2018-04-23                                                  0.0
# 2018-04-24                                                  0.0
#
# no_indicador   Pesquisa descontinuada (Frango vivo)  \
# dt_referencia
# 2018-04-18                                      0.0
# 2018-04-19                                      0.0
# 2018-04-20                                      0.0
# 2018-04-23                                      0.0
# 2018-04-24                                      0.0
#
# no_indicador   Soja industrial tipo 1 sc 60 Kg  \
# dt_referencia
# 2018-04-18                               76.56
# 2018-04-19                               76.00
# 2018-04-20                               75.87
# 2018-04-23                               76.15
# 2018-04-24                               76.09
#
# no_indicador   Suíno em pé tipo carne não integrado kg  \
# dt_referencia
# 2018-04-18                                        2.81
# 2018-04-19                                        2.81
# 2018-04-20                                        2.81
# 2018-04-23                                        2.81
# 2018-04-24                                        2.81
#
# no_indicador   Trigo pão PH 78 sc 60 Kg  Vaca em pé (padrão corte) arroba
# dt_referencia
# 2018-04-18                        38.66                            128.97
# 2018-04-19                        38.75                            129.12
# 2018-04-20                        39.18                            128.86
# 2018-04-23                        39.19                            128.79
# 2018-04-24                        39.31                            128.56

# %%
new_columns = {
    'Café em coco kg renda': 'CAFÉ',
    'Feijão Carioca tipo 1 sc 60 Kg': 'FEIJÃO DE COR',
    'Feijão preto tipo 1 sc 60 Kg': 'FEIJÃO PRETO',        
    'Milho amarelo tipo 1 sc 60 Kg': 'MILHO COMUM',
    'Soja industrial tipo 1 sc 60 Kg': 'SOJA INDUSTRIAL',
    'Trigo pão PH 78 sc 60 Kg': 'TRIGO',
    'Boi em pé arroba': 'BOI',
    'Pesquisa descontinuada (Frango vivo)': 'FRANGO',
    'Suíno em pé tipo carne não integrado kg': 'SUÍNO EM PÉ'
}

df = df.rename(columns=new_columns)
df.tail()
# Out:
# no_indicador   Arroz Agulhinha em casca tipo 1 sc 60 Kg     BOI  \
# dt_referencia
# 2018-04-18                                        46.22  141.17
# 2018-04-19                                        46.22  141.07
# 2018-04-20                                        46.22  141.06
# 2018-04-23                                        46.22  141.03
# 2018-04-24                                        46.22  140.83
#
# no_indicador   Café beneficiado bebida dura - tipo 6 sc 60 Kg  CAFÉ  \
# dt_referencia
# 2018-04-18                                             397.98  6.39
# 2018-04-19                                             397.81  6.39
# 2018-04-20                                             398.17  6.39
# 2018-04-23                                             397.36  6.39
# 2018-04-24                                             398.02  6.38
#
# no_indicador   Erva-mate folha em barranco arroba  FEIJÃO DE COR  \
# dt_referencia
# 2018-04-18                                   15.8          92.04
# 2018-04-19                                   15.8          96.97
# 2018-04-20                                   15.8          97.75
# 2018-04-23                                   15.8         101.70
# 2018-04-24                                   15.8         102.99
#
# no_indicador   FEIJÃO PRETO  Mandioca padrão de amido 580 g tonelada  \
# dt_referencia
# 2018-04-18           103.60                                   534.59
# 2018-04-19           103.80                                   526.31
# 2018-04-20           104.98                                   526.31
# 2018-04-23           105.43                                   525.86
# 2018-04-24           106.94                                   525.86
#
# no_indicador   MILHO COMUM  Pesquisa descontinuada (Algodão)  \
# dt_referencia
# 2018-04-18           30.55                               0.0
# 2018-04-19           30.60                               0.0
# 2018-04-20           30.66                               0.0
# 2018-04-23           30.66                               0.0
# 2018-04-24           30.70                               0.0
#
# no_indicador   Pesquisa descontinuada (Arroz em casca sequeiro)  FRANGO  \
# dt_referencia
# 2018-04-18                                                  0.0     0.0
# 2018-04-19                                                  0.0     0.0
# 2018-04-20                                                  0.0     0.0
# 2018-04-23                                                  0.0     0.0
# 2018-04-24                                                  0.0     0.0
#
# no_indicador   SOJA INDUSTRIAL  SUÍNO EM PÉ  TRIGO  \
# dt_referencia
# 2018-04-18               76.56         2.81  38.66
# 2018-04-19               76.00         2.81  38.75
# 2018-04-20               75.87         2.81  39.18
# 2018-04-23               76.15         2.81  39.19
# 2018-04-24               76.09         2.81  39.31
#
# no_indicador   Vaca em pé (padrão corte) arroba
# dt_referencia
# 2018-04-18                               128.97
# 2018-04-19                               129.12
# 2018-04-20                               128.86
# 2018-04-23                               128.79
# 2018-04-24                               128.56

# %%
drop_columns = {
    'Café beneficiado bebida dura - tipo 6 sc 60 Kg',
    'Arroz Agulhinha em casca tipo 1 sc 60 Kg',
    'Erva-mate folha em barranco arroba',
    'Pesquisa descontinuada (Algodão)',
    'Pesquisa descontinuada (Arroz em casca sequeiro)',
    'Vaca em pé (padrão corte) arroba'
}

df = df.drop(drop_columns, axis=1)
df.tail()
# Out:
# no_indicador      BOI  CAFÉ  FEIJÃO DE COR  FEIJÃO PRETO  \
# dt_referencia
# 2018-04-18     141.17  6.39          92.04        103.60
# 2018-04-19     141.07  6.39          96.97        103.80
# 2018-04-20     141.06  6.39          97.75        104.98
# 2018-04-23     141.03  6.39         101.70        105.43
# 2018-04-24     140.83  6.38         102.99        106.94
#
# no_indicador   Mandioca padrão de amido 580 g tonelada  MILHO COMUM  FRANGO  \
# dt_referencia
# 2018-04-18                                      534.59        30.55     0.0
# 2018-04-19                                      526.31        30.60     0.0
# 2018-04-20                                      526.31        30.66     0.0
# 2018-04-23                                      525.86        30.66     0.0
# 2018-04-24                                      525.86        30.70     0.0
#
# no_indicador   SOJA INDUSTRIAL  SUÍNO EM PÉ  TRIGO
# dt_referencia
# 2018-04-18               76.56         2.81  38.66
# 2018-04-19               76.00         2.81  38.75
# 2018-04-20               75.87         2.81  39.18
# 2018-04-23               76.15         2.81  39.19
# 2018-04-24               76.09         2.81  39.31

# %%
columnsTitles = [
    'CAFÉ',
    'FEIJÃO DE COR',
    'FEIJÃO PRETO',
    'MILHO COMUM',
    'SOJA INDUSTRIAL',
    'TRIGO',
    'BOI',
    'FRANGO',
    'SUÍNO EM PÉ'
]
    
df = df.reindex(columns=columnsTitles)
df.describe()
# Out:
# no_indicador         CAFÉ  FEIJÃO DE COR  FEIJÃO PRETO  MILHO COMUM  \
# count         2017.000000    2017.000000   2017.000000  2017.000000
# mean             5.859653     129.374879    109.899207    22.799197
# std              1.251165      66.893870     36.663990     5.594107
# min              0.000000       0.000000      0.000000     0.000000
# 25%              4.750000      88.450000     85.970000    19.570000
# 50%              6.290000     112.300000    105.030000    21.770000
# 75%              6.850000     147.890000    130.050000    24.440000
# max              8.200000     466.400000    220.010000    42.270000
#
# no_indicador  SOJA INDUSTRIAL        TRIGO          BOI       FRANGO  \
# count             2017.000000  2017.000000  2017.000000  2017.000000
# mean                57.124343    33.398647   116.829534     1.437362
# std                 11.975246     7.085983    25.292410     0.931904
# min                  0.000000     0.000000     0.000000     0.000000
# 25%                 46.330000    26.260000    95.920000     0.000000
# 50%                 59.480000    33.900000   114.150000     1.750000
# 75%                 65.840000    39.080000   142.030000     2.200000
# max                 85.070000    50.860000   153.690000     2.940000
#
# no_indicador  SUÍNO EM PÉ
# count         2017.000000
# mean             2.964274
# std              0.625796
# min              0.000000
# 25%              2.390000
# 50%              3.060000
# 75%              3.510000
# max              4.500000
