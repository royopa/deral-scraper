# %%
import pandas as pd
import os

def get_pandas_dataframe_base(path_file_base):
    df = pd.read_csv(path_file_base, sep=';', encoding='utf8')
    return df

# %%
base_file_name = 'precos_deral_base.csv'
path_file_base = os.path.join('bases', base_file_name)
df = get_pandas_dataframe_base(path_file_base)
df.tail(5)
# Out:
#       dt_referencia        no_produto  \
# 34603    2018-04-18         erva-mate
# 34604    2018-04-18             suíno
# 34605    2018-04-18              vaca
# 34606    2018-04-18  café beneficiado
# 34607    2018-04-18          mandioca
#
#                                          no_indicador  vr_real
# 34603              Erva-mate folha em barranco arroba    15.80
# 34604         Suíno em pé tipo carne não integrado kg     2.81
# 34605                Vaca em pé (padrão corte) arroba   128.97
# 34606  Café beneficiado bebida dura - tipo 6 sc 60 Kg   397.98
# 34607         Mandioca padrão de amido 580 g tonelada   534.59

# %%
df = df.pivot(index='dt_referencia', columns='no_indicador', values='vr_real')
df.tail()
# Out:
# no_indicador   Arroz Agulhinha em casca tipo 1 sc 60 Kg  Boi em pé arroba  \
# dt_referencia
# 2018-04-12                                        46.22            141.96
# 2018-04-13                                        46.22            142.07
# 2018-04-16                                        46.22            141.85
# 2018-04-17                                        46.22            141.18
# 2018-04-18                                        46.22            141.17
#
# no_indicador   Café beneficiado bebida dura - tipo 6 sc 60 Kg  \
# dt_referencia
# 2018-04-12                                             395.65
# 2018-04-13                                             395.84
# 2018-04-16                                             396.46
# 2018-04-17                                             398.01
# 2018-04-18                                             397.98
#
# no_indicador   Café em coco kg renda  Erva-mate folha em barranco arroba  \
# dt_referencia
# 2018-04-12                      6.40                               15.76
# 2018-04-13                      6.40                               15.80
# 2018-04-16                      6.39                               15.80
# 2018-04-17                      6.41                               15.69
# 2018-04-18                      6.39                               15.80
#
# no_indicador   Feijão Carioca tipo 1 sc 60 Kg  Feijão preto tipo 1 sc 60 Kg  \
# dt_referencia
# 2018-04-12                              90.05                        105.03
# 2018-04-13                              91.32                        104.28
# 2018-04-16                              93.47                        105.03
# 2018-04-17                              91.32                        102.85
# 2018-04-18                              92.04                        103.60
#
# no_indicador   Mandioca padrão de amido 580 g tonelada  \
# dt_referencia
# 2018-04-12                                      534.59
# 2018-04-13                                      534.59
# 2018-04-16                                      539.40
# 2018-04-17                                      539.40
# 2018-04-18                                      534.59
#
# no_indicador   Milho amarelo tipo 1 sc 60 Kg  \
# dt_referencia
# 2018-04-12                             30.55
# 2018-04-13                             30.57
# 2018-04-16                             30.55
# 2018-04-17                             30.57
# 2018-04-18                             30.55
#
# no_indicador   Pesquisa descontinuada (Algodão)  \
# dt_referencia
# 2018-04-12                                    0
# 2018-04-13                                    0
# 2018-04-16                                    0
# 2018-04-17                                    0
# 2018-04-18                                    0
#
# no_indicador   Pesquisa descontinuada (Arroz em casca sequeiro)  \
# dt_referencia
# 2018-04-12                                                    0
# 2018-04-13                                                    0
# 2018-04-16                                                    0
# 2018-04-17                                                    0
# 2018-04-18                                                    0
#
# no_indicador   Pesquisa descontinuada (Frango vivo)  \
# dt_referencia
# 2018-04-12                                        0
# 2018-04-13                                        0
# 2018-04-16                                        0
# 2018-04-17                                        0
# 2018-04-18                                        0
#
# no_indicador   Soja industrial tipo 1 sc 60 Kg  \
# dt_referencia
# 2018-04-12                               75.28
# 2018-04-13                               76.96
# 2018-04-16                               76.91
# 2018-04-17                               76.39
# 2018-04-18                               76.56
#
# no_indicador   Suíno em pé tipo carne não integrado kg  \
# dt_referencia
# 2018-04-12                                        2.86
# 2018-04-13                                        2.80
# 2018-04-16                                        2.80
# 2018-04-17                                        2.82
# 2018-04-18                                        2.81
#
# no_indicador   Trigo pão PH 78 sc 60 Kg  Vaca em pé (padrão corte) arroba
# dt_referencia
# 2018-04-12                        37.85                            130.05
# 2018-04-13                        37.90                            129.75
# 2018-04-16                        38.14                            129.40
# 2018-04-17                        38.66                            129.11
# 2018-04-18                        38.66                            128.97

# %%
new_columns = {
    'Café em coco kg renda': 'CAFÉ',
    'Feijão Carioca tipo 1 sc 60 Kg': 'FEIJÃO DE COR',
    'Feijão preto tipo 1 sc 60 Kg': 'FEIJÃO PRETO',        
    'Milho amarelo tipo 1 sc 60 Kg': 'MILHO COMUM',
    'Soja industrial tipo 1 sc 60 Kg': 'SOJA INDUSTRIAL',
    'Trigo pão PH 78 sc 60 Kg': 'TRIGO',
    'Boi em pé arroba': 'BOI',
    'Pesquisa descontinuada (Frango vivo)': 'FRANGO',
    'Suíno em pé tipo carne não integrado kg': 'SUÍNO EM PÉ'
}

df = df.rename(columns=new_columns)
df.tail()
# Out:
# no_indicador   Arroz Agulhinha em casca tipo 1 sc 60 Kg     BOI  \
# dt_referencia
# 2018-04-12                                        46.22  141.96
# 2018-04-13                                        46.22  142.07
# 2018-04-16                                        46.22  141.85
# 2018-04-17                                        46.22  141.18
# 2018-04-18                                        46.22  141.17
#
# no_indicador   Café beneficiado bebida dura - tipo 6 sc 60 Kg  CAFÉ  \
# dt_referencia
# 2018-04-12                                             395.65  6.40
# 2018-04-13                                             395.84  6.40
# 2018-04-16                                             396.46  6.39
# 2018-04-17                                             398.01  6.41
# 2018-04-18                                             397.98  6.39
#
# no_indicador   Erva-mate folha em barranco arroba  FEIJÃO DE COR  \
# dt_referencia
# 2018-04-12                                  15.76          90.05
# 2018-04-13                                  15.80          91.32
# 2018-04-16                                  15.80          93.47
# 2018-04-17                                  15.69          91.32
# 2018-04-18                                  15.80          92.04
#
# no_indicador   FEIJÃO PRETO  Mandioca padrão de amido 580 g tonelada  \
# dt_referencia
# 2018-04-12           105.03                                   534.59
# 2018-04-13           104.28                                   534.59
# 2018-04-16           105.03                                   539.40
# 2018-04-17           102.85                                   539.40
# 2018-04-18           103.60                                   534.59
#
# no_indicador   MILHO COMUM  Pesquisa descontinuada (Algodão)  \
# dt_referencia
# 2018-04-12           30.55                                 0
# 2018-04-13           30.57                                 0
# 2018-04-16           30.55                                 0
# 2018-04-17           30.57                                 0
# 2018-04-18           30.55                                 0
#
# no_indicador   Pesquisa descontinuada (Arroz em casca sequeiro)  FRANGO  \
# dt_referencia
# 2018-04-12                                                    0       0
# 2018-04-13                                                    0       0
# 2018-04-16                                                    0       0
# 2018-04-17                                                    0       0
# 2018-04-18                                                    0       0
#
# no_indicador   SOJA INDUSTRIAL  SUÍNO EM PÉ  TRIGO  \
# dt_referencia
# 2018-04-12               75.28         2.86  37.85
# 2018-04-13               76.96         2.80  37.90
# 2018-04-16               76.91         2.80  38.14
# 2018-04-17               76.39         2.82  38.66
# 2018-04-18               76.56         2.81  38.66
#
# no_indicador   Vaca em pé (padrão corte) arroba
# dt_referencia
# 2018-04-12                               130.05
# 2018-04-13                               129.75
# 2018-04-16                               129.40
# 2018-04-17                               129.11
# 2018-04-18                               128.97

# %%
drop_columns = {
    'Café beneficiado bebida dura - tipo 6 sc 60 Kg',
    'Arroz Agulhinha em casca tipo 1 sc 60 Kg',
    'Erva-mate folha em barranco arroba',
    'Pesquisa descontinuada (Algodão)',
    'Pesquisa descontinuada (Arroz em casca sequeiro)',
    'Vaca em pé (padrão corte) arroba'
}

df = df.drop(drop_columns, axis=1)
df.tail()
# Out:
# no_indicador      BOI  CAFÉ  FEIJÃO DE COR  FEIJÃO PRETO  \
# dt_referencia
# 2018-04-12     141.96  6.40          90.05        105.03
# 2018-04-13     142.07  6.40          91.32        104.28
# 2018-04-16     141.85  6.39          93.47        105.03
# 2018-04-17     141.18  6.41          91.32        102.85
# 2018-04-18     141.17  6.39          92.04        103.60
#
# no_indicador   Mandioca padrão de amido 580 g tonelada  MILHO COMUM  FRANGO  \
# dt_referencia
# 2018-04-12                                      534.59        30.55       0
# 2018-04-13                                      534.59        30.57       0
# 2018-04-16                                      539.40        30.55       0
# 2018-04-17                                      539.40        30.57       0
# 2018-04-18                                      534.59        30.55       0
#
# no_indicador   SOJA INDUSTRIAL  SUÍNO EM PÉ  TRIGO
# dt_referencia
# 2018-04-12               75.28         2.86  37.85
# 2018-04-13               76.96         2.80  37.90
# 2018-04-16               76.91         2.80  38.14
# 2018-04-17               76.39         2.82  38.66
# 2018-04-18               76.56         2.81  38.66

# %%
columnsTitles = [
    'CAFÉ',
    'FEIJÃO DE COR',
    'FEIJÃO PRETO',
    'MILHO COMUM',
    'SOJA INDUSTRIAL',
    'TRIGO',
    'BOI',
    'FRANGO',
    'SUÍNO EM PÉ'
]
    
df = df.reindex(columns=columnsTitles)
df.tail()
# Out:
# no_indicador   CAFÉ  FEIJÃO DE COR  FEIJÃO PRETO  MILHO COMUM  \
# dt_referencia
# 2018-04-12     6.40          90.05        105.03        30.55
# 2018-04-13     6.40          91.32        104.28        30.57
# 2018-04-16     6.39          93.47        105.03        30.55
# 2018-04-17     6.41          91.32        102.85        30.57
# 2018-04-18     6.39          92.04        103.60        30.55
#
# no_indicador   SOJA INDUSTRIAL  TRIGO     BOI  FRANGO  SUÍNO EM PÉ
# dt_referencia
# 2018-04-12               75.28  37.85  141.96       0         2.86
# 2018-04-13               76.96  37.90  142.07       0         2.80
# 2018-04-16               76.91  38.14  141.85       0         2.80
# 2018-04-17               76.39  38.66  141.18       0         2.82
# 2018-04-18               76.56  38.66  141.17       0         2.81
